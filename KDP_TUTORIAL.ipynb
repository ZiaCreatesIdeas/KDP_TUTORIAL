# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![FooterRaised.jpg](attachment:FooterRaised.jpg)

# %% [markdown]
# ![Error-Corrected_Raised_Footer_By_Point1.jpg](attachment:Error-Corrected_Raised_Footer_By_Point1.jpg)
